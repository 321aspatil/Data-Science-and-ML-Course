# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('banknotes.csv')

# %%
df
# Out:
#       Variance  Skewness  Curtosis  Entropy  Class
# 0      3.62160   8.66610   -2.8073 -0.44699      0
# 1      4.54590   8.16740   -2.4586 -1.46210      0
# 2      3.86600  -2.63830    1.9242  0.10645      0
# 3      3.45660   9.52280   -4.0112 -3.59440      0
# 4      0.32924  -4.45520    4.5718 -0.98880      0
# ...        ...       ...       ...      ...    ...
# 1367   0.40614   1.34920   -1.4501 -0.55949      1
# 1368  -1.38870  -4.87730    6.4774  0.34179      1
# 1369  -3.75030 -13.45860   17.5932 -2.77710      1
# 1370  -3.56370  -8.38270   12.3930 -1.28230      1
# 1371  -2.54190  -0.65804    2.6842  1.19520      1
#
# [1372 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Variance  1372 non-null   float64
#  1   Skewness  1372 non-null   float64
#  2   Curtosis  1372 non-null   float64
#  3   Entropy   1372 non-null   float64
#  4   Class     1372 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %% [markdown]
# ### Separate input and output data

# %%
#x=df.drop('Class',axis=1)
x=df[['Variance','Skewness','Curtosis','Entropy']]
y=df['Class']

# %% [markdown]
# ### Explore the data

# %%
sns.countplot(x=y);

# %%
y.value_counts()# 0:genune notes 1:fake notes
# Out:
# 0    762
# 1    610
# Name: Class, dtype: int64

# %% [markdown]
# ##### Note :Decision tree doesnt require scaling of features

# %%
sns.pairplot(df,hue='Class')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,stratify=y)#stratified sample gives representation from all the classses

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((1029, 4), (343, 4), (1029,), (343,))

# %%
y.value_counts()[0]/len(y)*100,y.value_counts()[1]/len(y)*100
# Out:
# (55.539358600583085, 44.460641399416915)

# %%
y_test.value_counts()[0]/len(y_test)*100,y_test.value_counts()[1]/len(y_test)*100
# Out:
# (55.68513119533528, 44.31486880466473)

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier=DecisionTreeClassifier(random_state=0)

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ### Plot the tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20,16))
plot_tree(classifier,fontsize=7,filled=True,class_names=['O','F'],feature_names=x.columns,precision=2);

# %% [markdown]
# ### Performance Evaluation

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import ConfusionMatrixDisplay,classification_report
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
ConfusionMatrixDisplay.from_predictions(y_test,y_pred);

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9766763848396501

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       191
#            1       0.96      0.99      0.97       152
#
#     accuracy                           0.98       343
#    macro avg       0.98      0.98      0.98       343
# weighted avg       0.98      0.98      0.98       343

# %%
classifier.feature_importances_
# Out:
# array([0.58011307, 0.23020975, 0.16121112, 0.02846606])

# %%
imp=classifier.feature_importances_

# %%
plt.figure(figsize=(16,9))
plt.title('Feature Importance')
plt.grid()
plt.xlabel('Feature Name')
plt.ylabel('%Importance')
plt.bar(x.columns,imp*100,color='magenta')
# Out:
# <BarContainer object of 4 artists>

# %%
newnotes=pd.DataFrame({
    'Variance':[3.86600,-3.75030,0.32925],
    'Skewness':[-2.63830,-13.45860,-4.45520],
    'Curtosis':[1.9242,17.5932,4.5718],
    'Entropy':[0.10645,-2.77710,-0.98880]
})
newnotes
# Out:
#    Variance  Skewness  Curtosis  Entropy
# 0   3.86600   -2.6383    1.9242  0.10645
# 1  -3.75030  -13.4586   17.5932 -2.77710
# 2   0.32925   -4.4552    4.5718 -0.98880

# %%
newnotes_pred=classifier.predict(newnotes)

# %%
newnotes_pred
# Out:
# array([0, 1, 0], dtype=int64)
