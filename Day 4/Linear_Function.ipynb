# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(0,10,0.25)
x
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25,
#        5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  ,
#        8.25, 8.5 , 8.75, 9.  , 9.25, 9.5 , 9.75])

# %%
x.size
# Out:
# 40

# %%
y=x*23.06+45.27

# %%
y
# Out:
# array([ 45.27 ,  51.035,  56.8  ,  62.565,  68.33 ,  74.095,  79.86 ,
#         85.625,  91.39 ,  97.155, 102.92 , 108.685, 114.45 , 120.215,
#        125.98 , 131.745, 137.51 , 143.275, 149.04 , 154.805, 160.57 ,
#        166.335, 172.1  , 177.865, 183.63 , 189.395, 195.16 , 200.925,
#        206.69 , 212.455, 218.22 , 223.985, 229.75 , 235.515, 241.28 ,
#        247.045, 252.81 , 258.575, 264.34 , 270.105])

# %%
plt.plot(x,y)

# %%
#Polynomial function
y=x**3+56

# %%
y
# Out:
# array([ 56.      ,  56.015625,  56.125   ,  56.421875,  57.      ,
#         57.953125,  59.375   ,  61.359375,  64.      ,  67.390625,
#         71.625   ,  76.796875,  83.      ,  90.328125,  98.875   ,
#        108.734375, 120.      , 132.765625, 147.125   , 163.171875,
#        181.      , 200.703125, 222.375   , 246.109375, 272.      ,
#        300.140625, 330.625   , 363.546875, 399.      , 437.078125,
#        477.875   , 521.484375, 568.      , 617.515625, 670.125   ,
#        725.921875, 785.      , 847.453125, 913.375   , 982.859375])

# %%
plt.plot(x,y)

# %%
plt.plot(x,np.log(x**2))
# Out:
# C:\Users\321as\AppData\Local\Temp\ipykernel_17284\2994243919.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x,np.log(x**2))
